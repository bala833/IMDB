# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('IMDB-Movie-Data.csv', index_col = 'Title')

# %%
df.head() #that movie finding more ranting   and search on spacy
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
# Rank                  1000 non-null int64
# Genre                 1000 non-null object
# Description           1000 non-null object
# Director              1000 non-null object
# Actors                1000 non-null object
# Year                  1000 non-null int64
# Duration              1000 non-null int64
# Rating                1000 non-null float64
# Votes                 1000 non-null int64
# Revenue (Millions)    872 non-null float64
# Metascore             936 non-null float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
dup_df = df.append(df)

# %%
dup_df.shape
# Out:
# (2000, 11)

# %%
dup_df.drop_duplicates(inplace=True,keep=False)

# %%
dup_df.shape
# Out:
# (0, 11)

# %%
df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Duration', 'Rating', 'Votes', 'Revenue (Millions)', 'Metascore'],
#       dtype='object')

# %%
df.rename(columns={'revenue (millions)': 'Revenue'}, inplace = True)

# %%
# for i in df.columns: # this in not correct way
#     print(i.lower())

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df.head(20)
# Out:
#                                          rank                       genre  \
# Title
# Guardians of the Galaxy                     1     Action,Adventure,Sci-Fi
# Prometheus                                  2    Adventure,Mystery,Sci-Fi
# Split                                       3             Horror,Thriller
# Sing                                        4     Animation,Comedy,Family
# Suicide Squad                               5    Action,Adventure,Fantasy
# The Great Wall                              6    Action,Adventure,Fantasy
# La La Land                                  7          Comedy,Drama,Music
# Mindhorn                                    8                      Comedy
# The Lost City of Z                          9  Action,Adventure,Biography
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# ...

# %%
df.isnull().sum()
# Out:
# rank             0
# genre            0
# description      0
# director         0
# actors           0
# year             0
# duration         0
# rating           0
# votes            0
# revenue        128
# metascore       64
# dtype: int64

# %%
temp = df.copy()
temp.head()
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
temp.dropna(axis = 1, inplace= True)

# %%
temp.shape
# Out:
# (1000, 9)

# %%
df.head(10)
# Out:
#                          rank                       genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# Suicide Squad               5    Action,Adventure,Fantasy
# The Great Wall              6    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# Passengers                 10     Adventure,Drama,Romance
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
df[['director', 'revenue', 'votes']].groupby(['director'], as_index = False).mean().sort_values(by = 'votes', ascending = False)
# Out:
#                         director     revenue         votes
# 108            Christopher Nolan  303.018000  1.311817e+06
# 261                James Cameron  760.510000  9.354080e+05
# 341                  Joss Whedon  541.135000  7.812415e+05
# 506            Quentin Tarantino  112.480000  6.398965e+05
# 608                   Tim Miller  363.020000  6.277970e+05
# 410              Martin Scorsese   91.622000  5.933048e+05
# 377                  Lee Unkrich  414.980000  5.866690e+05
# 490                  Pete Docter  324.715000  5.694460e+05
# 470              Olivier Nakache   13.180000  5.579650e+05
# 299                 Joe Johnston  176.640000  5.473680e+05
# 22                Alfonso Cuarón  154.685000  5.024995e+05
# 45                 Anthony Russo  333.915000  4.770090e+05
# 141                David Fincher  105.544000  4.619304e+05
# 642                  Zack Snyder  195.148000  4.603088e+05
# 114              Colin Trevorrow  652.180000  4.551690e+05
# ...

# %%
df[:][df.votes == 1311817]
# Out:
# Empty DataFrame
# Columns: [rank, genre, description, director, actors, year, duration, rating, votes, revenue, metascore]
# Index: []

# %%
1311817
# Out:
# 1311817

# %%
# df.isnull().sum()

# %%
# df.Director.value_counts().head()

# %%
# df.Actors.value_counts(ascending = False)

# %%
# https://www.kaggle.com/PromptCloudHQ/imdb-data

# %%
# df.Rating.value_counts()

# %%
# df[:][df['Rating'] >= 9]

# %%
# df[:][df['Votes'] >= df['Votes'].max()]

# %%
# df[:][df['Revenue (Millions)'] >= df['Revenue (Millions)'].max()]

# %%
# df[:][df['Metascore'] >= df['Metascore'].max()]

# %%
# df.Title.value_counts().max()

# %%
# df['Duration'].mean()
